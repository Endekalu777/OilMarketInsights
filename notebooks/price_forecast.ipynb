# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.price_forecasts import *

# %%
oil_data = pd.read_csv("../data/Oil_indicator.csv")

# %%
analysis = OilPriceAnalysis(oil_data)

# %%
analysis.prepare_data()

# %%
analysis.fit_arima(order = (2,1,2))
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
analysis.fit_garch()
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005192. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
analysis.fit_auto_arima()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=21011.493, Time=6.99 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=21016.359, Time=0.15 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=21008.505, Time=0.55 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=21008.365, Time=0.80 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=21014.423, Time=0.21 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=21010.221, Time=1.21 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=21010.125, Time=1.06 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=21011.937, Time=1.51 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=21006.424, Time=0.31 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=21008.280, Time=0.75 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=21008.184, Time=0.74 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=21006.564, Time=0.26 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=21009.998, Time=0.57 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# Total fit time: 15.150 seconds

# %%
analysis.fit_var()

# %%
analysis.fit_lstm()
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 16s 44ms/step - loss: 0.0254
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0026
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0021
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0018
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0017
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - loss: 0.0015
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - loss: 0.0015
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 13s 59ms/step - loss: 0.0014
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 0.0014
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0012
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0013
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0012
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0012
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0011
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0011
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0011
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0010
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0011
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 0.0012
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 9.8803e-04
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0011
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - loss: 9.8415e-04
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 9.6368e-04
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0011
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 9.7592e-04
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - loss: 0.0010
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 45ms/step - loss: 9.7944e-04
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - loss: 0.0011
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - loss: 9.6968e-04
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - loss: 0.0010
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 9.8021e-04
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 9.7916e-04
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 0.0010
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - loss: 9.6050e-04
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - loss: 9.9870e-04
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 9.7811e-04
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 9.6389e-04
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 0.0010
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 52ms/step - loss: 0.0010
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 9.6754e-04
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - loss: 9.2409e-04
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 9.2776e-04
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 49ms/step - loss: 9.9140e-04
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 9.5614e-04
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 54ms/step - loss: 0.0010
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 21s 54ms/step - loss: 9.2272e-04
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 9.3717e-04
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 50ms/step - loss: 9.4176e-04
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 47ms/step - loss: 9.6348e-04
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 49ms/step - loss: 8.4915e-04
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step

# %%
analysis.plot_all_results()
