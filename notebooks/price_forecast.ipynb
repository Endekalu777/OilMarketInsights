# %%
import sys
import os
import pandas as pd
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.price_forecasts import *

# %%
oil_data = pd.read_csv("../data/Oil_indicators.csv")

# %%
oil_data.head()
# Out:
#          Date  Price   Returns  Volatility    MA_50    MA_200  Momentum  \
# 0  1988-03-01  14.18 -0.037339    0.015044  16.2580  18.05060 -0.123609
# 1  1988-03-02  13.80 -0.026798    0.014953  16.2334  18.02645 -0.145511
# 2  1988-03-03  14.00  0.014493    0.015357  16.2014  18.00420 -0.134734
# 3  1988-03-04  14.00  0.000000    0.014894  16.1734  17.98145 -0.130435
# 4  1988-03-07  13.90 -0.007143    0.014595  16.1174  17.95795 -0.157576
#
#    Log_Returns
# 0    -0.038054
# 1    -0.027164
# 2     0.014389
# 3     0.000000
# 4    -0.007168

# %%
analysis = OilPriceAnalysis(oil_data)

# %%
analysis.prepare_data()

# %%
analysis.fit_arima(order = (2,1,2))
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# ...

# %%
analysis.fit_garch()
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0005192. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(

# %%
analysis.fit_auto_arima()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=21011.493, Time=8.47 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=21016.359, Time=0.19 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=21008.505, Time=0.67 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=21008.365, Time=1.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=21014.423, Time=0.18 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=21010.221, Time=1.23 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=21010.125, Time=1.10 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=21011.937, Time=2.26 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=21006.424, Time=0.87 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=21008.280, Time=0.74 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=21008.184, Time=1.66 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=21006.564, Time=0.43 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=21009.998, Time=1.06 sec
#
# Best model:  ARIMA(0,1,1)(0,0,0)[0]
# ...

# %%
analysis.fit_var()
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
analysis.fit_lstm()
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\week10\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 20s 56ms/step - loss: 0.0285
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 0.0025
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - loss: 0.0020
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 11s 52ms/step - loss: 0.0019
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 56ms/step - loss: 0.0017
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 21s 59ms/step - loss: 0.0016
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 53ms/step - loss: 0.0014
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 55ms/step - loss: 0.0015
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 0.0012
# Epoch 10/50
# ...

# %%
analysis.plot_all_results()

# %%
analysis.forecast_future()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# ...
