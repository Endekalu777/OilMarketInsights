# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.Oil_price_analysis import *

# %%
analysis = OilPriceAnalysis("../data/BrentOilPrices.csv", "../data/country_inflation_data/China_Inflation_Rate.csv", "../data/GDP/GDPChina.csv", "../data/unemployment_rate/China_Unemployment_Rate.csv")
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\scripts\Oil_price_analysis.py:12: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.oil_prices = pd.read_csv(oil_prices_file, parse_dates=['Date'], dayfirst=True)
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\scripts\Oil_price_analysis.py:13: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.inflation = pd.read_csv(inflation_file, parse_dates=['Date'], dayfirst=True)
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\scripts\Oil_price_analysis.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
analysis.preprocess_data()

# %%
analysis.plot_data()

# %%
analysis.fit_var_model()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 05, Nov, 2024
# Time:                     00:57:58
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                    61.1988
# Nobs:                     33.0000    HQIC:                   60.1155
# Log likelihood:          -1134.14    FPE:                7.83213e+25
# AIC:                      59.5662    Det(Omega_mle):     2.98496e+25
# --------------------------------------------------------------------
# Results for equation Price
# ...
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        5.728493         5.196739            1.102           0.270
# L1.Price                    -0.156001         0.242700           -0.643           0.520
# ...
