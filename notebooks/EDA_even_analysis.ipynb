# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.EDA_event_analysis import *

# %%
filepath = "../data/BrentOilPrices.csv"
analysis = EDAEventAnalysis(filepath)
# Out:
# c:\Users\Ashis\Desktop\KAIM Program 2\week_10\scripts\EDA_event_analysis.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   self.df['Date'] = pd.to_datetime(self.df['Date'])

# %%
analysis.perform_eda()
# Out:
# 'Data Summary:'
# count    9011.000000
# mean       48.420782
# std        32.860110
# min         9.100000
# 25%        19.050000
# 50%        38.570000
# 75%        70.090000
# max       143.950000
# Name: Price, dtype: float64

# %%
analysis.event_analysis()
