# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.pre_processor import *

# %%
analysis = PreProcessor("../data/BrentOilPrices.csv", "../data/external_factors/merged_indicators.csv")

# %%
brent_df = analysis.load_brent_data()

# %%
external_df = analysis.load_external_data()

# %%
merge_df = analysis.merge_data()

# %%
analysis.pre_process_data()
# Out:
# Analyzing dataset: ../data/BrentOilPrices.csv
#
# Dataset Description:
#               Price          year  GDP Growth (%)  Inflation Rate (%)  \
# count  73800.000000  73800.000000    7.380000e+04        73800.000000
# mean      47.004720   2003.649512    3.301298e+12          318.165198
# std       32.580882      9.335941    5.325008e+12          646.966194
# min        9.100000   1988.000000    4.077963e+08            0.030568
# 25%       18.900000   1996.000000    1.230579e+11           66.616642
# 50%       33.260000   2004.000000    3.955372e+11           97.202751
# 75%       67.672500   2012.000000    5.236438e+12          126.601512
# max      143.950000   2020.000000    2.152140e+13         2140.219429
#
#        Unemployment Rate (%)  Exchange Rate (Local Currency per USD)  \
# count           73800.000000                            73800.000000
# mean                6.276870                             6064.572475
# std                 3.492012                            13793.721899
# min                 0.694000                                0.268828
# 25%                 3.250000                                3.671000
# 50%                 5.636000                                6.143434
# 75%                 8.978000                             1749.173736
# max                15.776000                            42000.000000
#
#        Renewable Energy Consumption (%)  Environmental Tax Revenue (% of GDP)  \
# count                      73800.000000                          73800.000000
# mean                           5.095865                              0.948279
# std                            7.579178                              0.322745
# min                            0.000000                              0.713000
# 25%                            0.100000                              0.713000
# 50%                            1.100000                              0.713000
# 75%                            7.906890                              1.391000
# max                           33.900000                              1.391000
#
#        Net Trade (BoP, current US$)  Natural Gas Electricity Production (%)
# count                  7.380000e+04                            73800.000000
# mean                   3.565990e+10                               39.696960
# std                    2.045035e+11                               29.059871
# min                   -7.635330e+11                                0.253542
# 25%                    3.840000e+09                               15.735220
# 50%                    1.222400e+10                               36.418917
# 75%                    7.940925e+10                               55.520708
# max                    3.860632e+11                               98.620858
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73800 entries, 0 to 73799
# Data columns (total 13 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date_x                                  73800 non-null  datetime64[ns]
#  1   Price                                   73800 non-null  float64
#  2   year                                    73800 non-null  float64
#  3   country                                 73800 non-null  object
#  4   date_y                                  73800 non-null  datetime64[ns]
#  5   GDP Growth (%)                          73800 non-null  float64
#  6   Inflation Rate (%)                      73800 non-null  float64
#  7   Unemployment Rate (%)                   73800 non-null  float64
#  8   Exchange Rate (Local Currency per USD)  73800 non-null  float64
#  9   Renewable Energy Consumption (%)        73800 non-null  float64
#  10  Environmental Tax Revenue (% of GDP)    73800 non-null  float64
#  11  Net Trade (BoP, current US$)            73800 non-null  float64
#  12  Natural Gas Electricity Production (%)  73800 non-null  float64
# dtypes: datetime64[ns](2), float64(10), object(1)
# memory usage: 7.3+ MB
# None
# Missing Values:
# date_x                                    0
# Price                                     0
# year                                      0
# country                                   0
# date_y                                    0
# GDP Growth (%)                            0
# Inflation Rate (%)                        0
# Unemployment Rate (%)                     0
# Exchange Rate (Local Currency per USD)    0
# Renewable Energy Consumption (%)          0
# Environmental Tax Revenue (% of GDP)      0
# Net Trade (BoP, current US$)              0
# Natural Gas Electricity Production (%)    0
# dtype: int64
# Outlier Detection:
# Missing Values Report (Percentage):
# Series([], dtype: float64)

# %%
merge_df.to_csv("../data/merged_clean_data.csv", index = False)
